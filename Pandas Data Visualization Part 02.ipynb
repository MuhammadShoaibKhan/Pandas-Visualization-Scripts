# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#################
### Data
#################

flowers = pd.DataFrame({
    'species':np.random.choice(a=['Alyssum','Amaranthus','Aster','Rose', 'Lily', 'Jonquil'], size=1000),
    'shades':np.random.choice(a=['red','blue'], size=1000),
    'prod_summer': 260+np.random.randn(1000)*np.sin(np.pi/4),
    'prod_winter': 150+np.random.normal(100, 30, 1000),
    'prod_fall': 355+np.random.normal(300, 130, 1000),
    'prod_spring': 440+np.random.normal(450, 70, 1000),
    'num_orders': np.random.randn(1000)*2

    }
    ,index=pd.date_range('2019-01-01', periods=1000)
)

# %%
a = pd.DataFrame({
    'A':['m','m','m','n','n','n','o','o','o'],
    'a1':[1,2,3,  1,2,-3,  300,324,323],
    'a2':[90,91,95,  150,151,-152,   343,313,311],
    'a3':[10,12,13,  22,21,-23,   333,290,299],
    'a4':[90,91,95,  150,151,-152,   311,314,317]
})

# %%
b = pd.DataFrame({
    'x': [1,2,3,4,5,6,6,5,4,3,2,1],
    'y': [-1,-2,-3,-4,-5,-6,-6,-5,-4,-3,-2,-1]
})

# %%
g = pd.DataFrame({
    'A':['m','m','m','n','n','n','o','o','o'],
    'a1':[1,2,3,  1,2,3,  300,324,323],
    'a2':[90,91,95,  150,151,152,   343,313,311],
    'a3':[10,10,30,  15,21,27,   333,290,299],
    'a4':[1e3,1e3,1e3,  15,13,12,   304,314,317]
})

# %% [markdown]
# ### Scatter Matrix

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix (flowers, alpha = .2, figsize = (10,10), diagonal = 'kde')
# Out:
# array([[<AxesSubplot:xlabel='prod_summer', ylabel='prod_summer'>,
#         <AxesSubplot:xlabel='prod_winter', ylabel='prod_summer'>,
#         <AxesSubplot:xlabel='prod_fall', ylabel='prod_summer'>,
#         <AxesSubplot:xlabel='prod_spring', ylabel='prod_summer'>,
#         <AxesSubplot:xlabel='num_orders', ylabel='prod_summer'>],
#        [<AxesSubplot:xlabel='prod_summer', ylabel='prod_winter'>,
#         <AxesSubplot:xlabel='prod_winter', ylabel='prod_winter'>,
#         <AxesSubplot:xlabel='prod_fall', ylabel='prod_winter'>,
#         <AxesSubplot:xlabel='prod_spring', ylabel='prod_winter'>,
#         <AxesSubplot:xlabel='num_orders', ylabel='prod_winter'>],
#        [<AxesSubplot:xlabel='prod_summer', ylabel='prod_fall'>,
#         <AxesSubplot:xlabel='prod_winter', ylabel='prod_fall'>,
#         <AxesSubplot:xlabel='prod_fall', ylabel='prod_fall'>,
#         <AxesSubplot:xlabel='prod_spring', ylabel='prod_fall'>,
#         <AxesSubplot:xlabel='num_orders', ylabel='prod_fall'>],
#        [<AxesSubplot:xlabel='prod_summer', ylabel='prod_spring'>,
#         <AxesSubplot:xlabel='prod_winter', ylabel='prod_spring'>,
#         <AxesSubplot:xlabel='prod_fall', ylabel='prod_spring'>,
#         <AxesSubplot:xlabel='prod_spring', ylabel='prod_spring'>,
#         <AxesSubplot:xlabel='num_orders', ylabel='prod_spring'>],
#        [<AxesSubplot:xlabel='prod_summer', ylabel='num_orders'>,
#         <AxesSubplot:xlabel='prod_winter', ylabel='num_orders'>,
#         <AxesSubplot:xlabel='prod_fall', ylabel='num_orders'>,
#         <AxesSubplot:xlabel='prod_spring', ylabel='num_orders'>,
#         <AxesSubplot:xlabel='num_orders', ylabel='num_orders'>]],
#       dtype=object)

# %%
flowers['prod_summer'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
flowers['prod_summer'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Andrews Curve
# Useful for Multivariate Data Analysis

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(flowers.iloc[0:10,[0,2,3]], 'species')
# Out:
# <AxesSubplot:>

# %%
a
# Out:
#    A   a1   a2   a3   a4
# 0  m    1   90   10   90
# 1  m    2   91   12   91
# 2  m    3   95   13   95
# 3  n    1  150   22  150
# 4  n    2  151   21  151
# 5  n   -3 -152  -23 -152
# 6  o  300  343  333  311
# 7  o  324  313  290  314
# 8  o  323  311  299  317

# %%
andrews_curves(a, 'A')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Parallel Coordinates

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(flowers.iloc[0:10,[0,2,3,4]], 'species')
# Out:
# <AxesSubplot:>

# %%
parallel_coordinates(a,'A')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Lag Plot

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(flowers.iloc[:,[2,3,4,5]])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
b
# Out:
#     x  y
# 0   1 -1
# 1   2 -2
# 2   3 -3
# 3   4 -4
# 4   5 -5
# 5   6 -6
# 6   6 -6
# 7   5 -5
# 8   4 -4
# 9   3 -3
# 10  2 -2
# 11  1 -1

# %%
lag_plot(b)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# ### RadViz

# %%
from pandas.plotting import radviz

# %%
radviz(flowers.iloc[:,[0,2,3,4,5]],'species', alpha = 0.25)
# Out:
# <AxesSubplot:>

# %%
g
# Out:
#    A   a1   a2   a3      a4
# 0  m    1   90   10  1000.0
# 1  m    2   91   10  1000.0
# 2  m    3   95   30  1000.0
# 3  n    1  150   15    15.0
# 4  n    2  151   21    13.0
# 5  n    3  152   27    12.0
# 6  o  300  343  333   304.0
# 7  o  324  313  290   314.0
# 8  o  323  311  299   317.0

# %%
radviz(g, 'A', alpha = 0.25, s=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bootstrap

# %%
from pandas.plotting import bootstrap_plot

# %%
bootstrap_plot(flowers.iloc[:,3], size = 50, samples = 100,color = 'grey')

# %% [markdown]
# ### Autocorrelation

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(flowers.iloc[:,3])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
autocorrelation_plot(np.sin(np.linspace(0,100)))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>
